# %% [markdown]
# # Kaggle: Michael Jordan, Kobe Bryant and Lebron James stats

# %% [markdown]
# ## 1. Introducción

# %% [markdown]
# Para este proyecto se utilizaran diferentes bases de datos que proporcionan información sobre todas las estadisticas de tres de los mejores jugadores de la historia del baloncesto: Michael Jordan, Kobe Bryant y Lebron James.
#
# Los datasets utilizados para este proyecto serán:
#
#     1. allgames_stats.csv: BD que proporciona las estadísticas de todos los partidos de los 3 jugadores
#     2. per_game_stats.csv: BD que proporciona las estadísticas medias de cada temporada de los 3 jugadores

# %% [markdown]
# ## 2. Objetivos

# %% [markdown]
# Los objetivos de este proyecto serán dos. Por una banda, realizar un analisis de los datos del dataset donde se encuentran las estadisticas de cada jugador por temporada y de este modo extraer conclusiones. Por otra banda, realizar la predicción de un atributo tomandolo como el "target" del problema, es decir, realizar un problema de regresión lineal.
#
# De esta forma el objetivo principal de este proyecto será contestar las siguientes 2 preguntas:
#
# 1. ¿Quién es estadisticamente el mejor jugador de los tres? -> Donde se realizará un analisis de los datos comparando las diferentes estadísticas para poder llegar a una respuesta.
#
# 2. ¿Qué puntuación ha hecho el jugador? -> Donde para los dos datasets se realizarán varios modelos capaces de predecir la puntuación que haya realizado el jugador, se compará cual es el mejor y se analizarán los resultados obtenidos por dichos modelos, se tratará un problema de regresión lineal.

# %% [markdown]
# ## 3. Exploratory Data Analysis

# %% [markdown]
# ### 3.1. Imports y primeras visualizaciones

# %% [markdown]
# Antes de comenzar, realizaremos los imports de todas las librerias necesárias para realizar esta practica y cargaremos los datos de los datasets que utilizaremos

# %%
from sklearn.datasets import make_regression
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
import scipy.stats
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn import preprocessing
import sklearn
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from statistics import mean
from sklearn import svm 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

import warnings 
warnings.filterwarnings('ignore')

def load_dataset(path):
    dataset = pd.read_csv(path, header=0, delimiter=',')
    return dataset

# carreguem dataset 

dataset_per_game_stats = load_dataset('datasets/per_game_stats.csv')
data_per_game_stats = dataset_per_game_stats.values

dataset_allgames_stats = load_dataset('datasets/allgames_stats.csv')
data_allgames_stats = dataset_allgames_stats.values

# %% [markdown]
# Realizaremos una primera visualización de los datos para conocer la dimensión y el número de atributos con los que operaremos

# %%
print("Dataset per_game_stats")
dataset_per_game_stats.head()
# Out:
# Dataset per_game_stats
#     Season  Age   Tm   Lg Pos   G  GS    MP    FG   FGA  ...  DRB  TRB  AST  \
# 0  2003-04   19  CLE  NBA  SG  79  79  39.5   7.9  18.9  ...  4.2  5.5  5.9
# 1  2004-05   20  CLE  NBA  SF  80  80  42.4   9.9  21.1  ...  6.0  7.4  7.2
# 2  2005-06   21  CLE  NBA  SF  79  79  42.5  11.1  23.1  ...  6.1  7.0  6.6
# 3  2006-07   22  CLE  NBA  SF  78  78  40.9   9.9  20.8  ...  5.7  6.7  6.0
# 4  2007-08   23  CLE  NBA  SF  75  74  40.4  10.6  21.9  ...  6.1  7.9  7.2
#
#    STL  BLK  TOV   PF   PTS        Player          RSorPO
# 0  1.6  0.7  3.5  1.9  20.9  Lebron James  Regular Season
# 1  2.2  0.7  3.3  1.8  27.2  Lebron James  Regular Season
# 2  1.6  0.8  3.3  2.3  31.4  Lebron James  Regular Season
# 3  1.6  0.7  3.2  2.2  27.3  Lebron James  Regular Season
# 4  1.8  1.1  3.4  2.2  30.0  Lebron James  Regular Season
#
# [5 rows x 32 columns]

# %%
print("Dataset allgames_stats")
dataset_allgames_stats.head()
# Out:
# Dataset allgames_stats
#    G        Date   Tm    X  Opp Result  GS     MP   FG  FGA  ...  TRB  AST  \
# 0  1  1996-11-03  LAL  NaN  MIN      W   0   6:00  0.0  1.0  ...    1    0
# 1  2  1996-11-05  LAL    @  NYK      W   0   3:00  0.0  1.0  ...    0    0
# 2  3  1996-11-06  LAL    @  CHH      L   0   7:00  2.0  3.0  ...    0    0
# 3  4  1996-11-08  LAL    @  TOR      L   0  17:00  3.0  8.0  ...    3    0
# 4  5  1996-11-10  LAL  NaN  ATL      W   0   8:00  0.0  3.0  ...    3    1
#
#    STL  BLK  TOV  PF   PTS  GmSc       Player          RSorPO
# 0  0.0  1.0    1   1   0.0  -1.1  Kobe Bryant  Regular Season
# 1  0.0  0.0    1   0   1.0  -1.1  Kobe Bryant  Regular Season
# 2  0.0  0.0    3   0   5.0   0.7  Kobe Bryant  Regular Season
# 3  0.0  1.0    0   3  10.0   5.2  Kobe Bryant  Regular Season
# 4  0.0  0.0    0   0   2.0   1.9  Kobe Bryant  Regular Season
#
# [5 rows x 29 columns]

# %%
print("Dataset per_game_stats")
print("Dimensión base de datos: ", dataset_per_game_stats.shape)
print("Número de atributos: ", dataset_per_game_stats.columns.size)
print(" ")
print("Dataset allgames_stats")
print("Dimensión base de datos: ", dataset_allgames_stats.shape)
print("Número de atributos: ", dataset_allgames_stats.columns.size)
# Out:
# Dataset per_game_stats
# Dimensión base de datos:  (92, 32)
# Número de atributos:  32
#
# Dataset allgames_stats
# Dimensión base de datos:  (4254, 29)
# Número de atributos:  29

# %% [markdown]
# **Dataset per_game_stats.csv**
# Este dataset contiene las estadisticas y datos medios por temporada de cada uno de los tres jugadores. Como podemos observar, está formado por un total de 92 muestras y 32 atributos diferentes.
#
# **Dataset allgames_stats.csv**
# Este dataset contiene las estadisticas y datos de todos los partidos jugados de los 3 jugadores. Por ese mismo motivo el dataset está formado por un total de 4254 muestras y 29 atributos diferentes.

# %% [markdown]
# ### 3.2. Tipos de datos y seleccion de atributo target

# %% [markdown]
# A continuación comprobaremos el tipo de datos que contienen nuestros dataset

# %%
print("Dataset per_game_stats")
dataset_per_game_stats.dtypes
# Out:
# Dataset per_game_stats
# Season     object
# Age         int64
# Tm         object
# Lg         object
# Pos        object
# G           int64
# GS          int64
# MP        float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# Player     object
# RSorPO     object
# dtype: object

# %% [markdown]
# Para este dataset podemos que la mayoria de atributos son de tipo númerico ya que se tratan de atributos estadisticos sobre la temporada como podrian ser los puntos, rebotes, asistencias, etc. Tambien existen una serie de atributos de tipo string como podrian ser el nombre, la temporada, etc.
#
# Estos atributos no numéricos seran tratados más adelante en el apartado de "Preprocessing", de igual modo también será necessario eliminar atributos númericos no necessarios en dicho apartado para realizar el problema ya que una base de datos con muchos atributos podria afectar a la hora de realizar predicciones.

# %%
print("Dataset allgames_stats")
dataset_allgames_stats.dtypes
# Out:
# Dataset allgames_stats
# G           int64
# Date       object
# Tm         object
# X          object
# Opp        object
# Result     object
# GS          int64
# MP         object
# FG        float64
# FGA       float64
# FG%       float64
# 3P          int64
# 3PA         int64
# 3P%       float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB         int64
# AST         int64
# STL       float64
# BLK       float64
# TOV         int64
# PF          int64
# PTS       float64
# GmSc      float64
# Player     object
# RSorPO     object
# dtype: object

# %% [markdown]
# De forma similar al dataset anterior, la mayoria de atributos que contiene este también son de tipo numerico ya que son los que hacen referencia a las estadisticas por partido. También existen una série de atributos de tipo no numerico como el jugador, el equipo, el rival, etc.

# %% [markdown]
# El atributo **target** a predecir para las dos base de datos seran los **PTS** haciendo referéncia a los puntos por partido para el dataset allgames_stats.csv y a la media de puntos por partido de cada temporada para el dataset per_game_stats.csv

# %% [markdown]
# ### 3.3. Corrección Atributos

# %% [markdown]
# Antes de realizar las matrices de correlación, es necesario realizar una serie de transformaciones para este ultimo dataset (allgames_stats.csv) ya que contiene atributos de tipo object (local, minutos jugados, resultado) los cuales son interesantes visualizar en la matriz de correlación y al ser de tipo object no quedarán representados. Por lo tanto, procedemos a realizar estas transformaciones.

# %% [markdown]
# El atributo "X" hace referencia a si el jugador ha jugado el partido como local (valor nulo) o visitante (valor @), por lo tanto pararemos los valores nulos a 1 y los valores @ a 0

# %%
for i in range(dataset_allgames_stats.shape[0]):
    if dataset_allgames_stats["X"][i] == "@":
        dataset_allgames_stats["X"][i] = 0
    else:
        dataset_allgames_stats["X"][i] = 1
        
dataset_allgames_stats["X"] = pd.to_numeric(dataset_allgames_stats["X"])

# %% [markdown]
# Ahora procedemos a fijarnos en el atributo "Results". Al ser de tipo object lo pasaremos a tipo int de la siguiente forma que se ha explicado anteriormente para poder operar con él.

# %%
for i in range(dataset_allgames_stats.shape[0]):
    if dataset_allgames_stats["Result"][i] == "L":
        dataset_allgames_stats["Result"][i] = 0
    elif dataset_allgames_stats["Result"][i] == "W":
        dataset_allgames_stats["Result"][i] = 1
        
dataset_allgames_stats["Result"] = pd.to_numeric(dataset_allgames_stats["Result"])

# %% [markdown]
# El atributo "MP" hace referéncia a los minutos jugados el cual también es de tipo object. Pasaremos los minutos de tipo object a tipo numerico

# %%
for i in range(dataset_allgames_stats.shape[0]):
    minuto = dataset_allgames_stats["MP"][i]
    m = ""
    for x in minuto:
        if x != ":":
            m = m + x
        else:
            dataset_allgames_stats["MP"][i] = int(m)
            break
dataset_allgames_stats["MP"] = pd.to_numeric(dataset_allgames_stats["MP"])

# %% [markdown]
# ### 3.4. Matrices de correlación

# %% [markdown]
# Una vez ya tenemos los atributos que más nos pueden interesar corregidos, procedemos a realizar las matrices de correlación para visualizar la correlación de los atributos.

# %%
print("Matriz de correlación Dataset per_game_stats")
correlacio = dataset_per_game_stats.corr()
plt.figure()
ax = sns.heatmap(correlacio, annot=True, annot_kws={"size": 4.5})
# Out:
# Matriz de correlación Dataset per_game_stats

# %% [markdown]
# Como se puede observar, los atributos para este dataset están bastante bien correlacionados entre si. Concretamente, nuestro atributo a predecir PTS (puntos medios por temporada) obtiene las correlacioenes más altas con los atributos FG (0.97), FGA (0.92), 2P (0.92), FTA (0.79), FT (0.51), 2PA (0.55) y STL (0.64) .
# Que hacen referéncia a:
#
#     - FG: Media de canastas por partido
#     - FGA: Media de intentos de canasta por partido
#     - 2P: Media de canastas de 2 puntos por partido
#     - 2PA: Media de intentos de canasta de 2 puntos por partido
#     - FTA: Media de intentos de tiro libre por partido
#     - FT: Media de canastas de tiro libre por partido
#     - STL: Media de robos por partido

# %%
print("Matriz de correlación Dataset allgames_stats")
correlacio = dataset_allgames_stats.corr()
plt.figure()
ax = sns.heatmap(correlacio, annot=True, annot_kws={"size": 4.5})
# Out:
# Matriz de correlación Dataset allgames_stats

# %% [markdown]
# A diferéncia del dataset anterior, en general los atributos de este están mucho menos correlacionados entre sí. Nuestro atributo target PTS para este dataset es el que tiene las mejores correlaciones comparandolo con el resto de atributos, en canvio, sus correlaciones son inferiores que las del dataset anterior. Nuestro target obtiene las correlaciones mas altas con los atributos FG (0.91), FGA (0.75), GmSc (0.87) y FT (0.59). Que hacen referéncia a:
#
#     - FG: Media de canastas por partido
#     - FGA: Media de intentos de canasta por partido
#     - GmSc: Puntuación de rendimiento del jugador en el partido
#     - FT: Media de canastas de tiro libre por partido

# %% [markdown]
# En principio, viendo como estan correalcionados los dos datasets podemos pensar que obtendremos mejores resultados en el dataset per_game_stats.csv al contener una mejor correlación de los atributos.

# %% [markdown]
# ### 3.5. Pairplot

# %% [markdown]
# A continuación, realizaremos un pairplot para cada dataset con los atributos más influyentes.

# %%
# Pairplot dataset_per_game_stats
sns.pairplot(dataset_per_game_stats[['FG', 'FGA', 'FT', 'FTA', '2P', '2PA', 'STL', 'PTS']])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Pairplot dataset_allgames_stats
sns.pairplot(dataset_allgames_stats[['FG', 'FGA', 'FT', 'GmSc', 'PTS']])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 3.6. Distribución del atributo target

# %% [markdown]
# A continuación comprobaremos para cada dataset como esta distribuido nuestro atributo target PTS.

# %%
plt.figure()
sns.displot(dataset_per_game_stats, x='PTS',binwidth=0.5, edgecolor='black', 
linewidth=0.5)
plt.title("Dataset per_game_stats.csv")
plt.show()

# %% [markdown]
# Como podemos observar, para el primer dataset encontramos que la distribución es un poco irregular pero que la mayoria de muestras contienen una media de puntos aproximadamente de entre 25 y 35 puntos.

# %%
plt.figure()
sns.displot(dataset_allgames_stats, x='PTS',binwidth=0.5, edgecolor='black', 
linewidth=0.5)
plt.title("Dataset allgames_stats.csv")
plt.show()

# %% [markdown]
# Para este dataset en canvio podemos observar como hay una gran concentración de muestras que contienen aproximadamente de entre 20 a 35 puntos. Similar al anterior dataset.

# %% [markdown]
# ### 3.7. ¿Quién es estadísticamente el mejor jugador? (Objetivo 1)

# %% [markdown]
# Una vez corregido los atributos y antes de continuar con el apartado de preprocesamiento de los datos que será necesario para realizar las predicciones me gustaria realizar un analisis de los datos con el objetivo de alcanzar el primer objetivo planteado en el proyecto:
#
# ¿Quién es estadísticamente el mejor jugador?

# %% [markdown]
# Para este apartado utilizaremos el dataset **per_game_stats.csv** que contiene las estadisticas medias de todas las temporadas de cada jugador. Primero ordenaremos las temporadas del dataset y separaremos los datos de cada jugador.

# %%
for i in range(dataset_per_game_stats.shape[0]):
    año = dataset_per_game_stats["Season"][i]
    convert = año[0:4]
    dataset_per_game_stats["Season"][i] = int(convert)
dataset_per_game_stats["Season"] = pd.to_numeric(dataset_per_game_stats["Season"])
  
dataset_per_game_statsOrd = dataset_per_game_stats.sort_values("Season")
    
MJ = dataset_per_game_statsOrd[dataset_per_game_statsOrd.Player == "Michael Jordan"]
MJ_RS = MJ[MJ.RSorPO == "Regular Season"] 
MJ_PO = MJ[MJ.RSorPO == "Playoffs"] 

KB = dataset_per_game_statsOrd[dataset_per_game_statsOrd.Player == "Kobe Bryant"]
KB_RS = KB[KB.RSorPO == "Regular Season"] 
KB_PO = KB[KB.RSorPO == "Playoffs"] 

LB = dataset_per_game_statsOrd[dataset_per_game_statsOrd.Player == "Lebron James"]
LB_RS = LB[LB.RSorPO == "Regular Season"] 
LB_PO = LB[LB.RSorPO == "Playoffs"]

# %% [markdown]
# Para poder responder a la pregunta, analizaremos de cada jugador las estadisticas más importantes o más relevantes de un jugador de baloncesto. Estas estadísticas son los **puntos, los rebotes y las asistencias**.
#
# Analizar unicamente estas estadísticas no es una métrica infalible para saber cual de los 3 es el mejor ya que existen muchas otras que tambien influyen para determinar si un jugador es estadisticamente bueno. Además, tampoco podemos estudiar el impacto que tienen sus acciones o dichas estadisticas en un partido pero si que nos servira para realizar una proximación de quien es el mejor.

# %% [markdown]
# ### Puntos por partido

# %% [markdown]
# Primero realizaremos una primera visualización general de los puntos por partido de cada temporada para los 3 jugadores

# %%
g = sns.lineplot(x=dataset_per_game_stats["Season"], y= dataset_per_game_stats["PTS"], color="red", hue = dataset_per_game_stats["Player"], sort=True)
g.tick_params(axis="x", rotation=90)

# %% [markdown]
# Seguidamente realizaremos una visualizción para cada uno de los jugadores

# %%
g = sns.lineplot(x=MJ_RS["Season"], y= MJ_RS["PTS"], color="red", sort=True)
g.tick_params(axis="x", rotation=90)
text = plt.title("Micahel Jordan points per game")

# %%
g = sns.lineplot(x=KB_RS["Season"], y= KB_RS["PTS"], color="purple", sort=True)
g.tick_params(axis="x", rotation=90)
text = plt.title("Kobe Bryant points per game")

# %%
g = sns.lineplot(x=LB_RS["Season"], y= LB_RS["PTS"], color="yellow", sort=True)
g.tick_params(axis="x", rotation=90)
text = plt.title("Lebron James points per game")

# %% [markdown]
# Como podemos observar en las graficas, Michael Jordan es el que tiene el valor de media de puntos por partido más alto en una temporada con un valor de 37.5 puntos y le seguiria Kobe Bryant con una media de 35.4 puntos.
#
# En cuanto a rendimiento podemos ver que Michael Jordan obtiene los valores más altos de puntos en sus primeras temporada y a medida que pasan los años su rendimiento disminuye drásticamente. Kobe Bryant pasa por altibajos en cuanto a puntos pero sin duda Lebron James es el jugador que se mantiene más regular de los tres en cuanto a media de puntos por partido aun no siendo el que tiene los valores más altos.
#
# Dichos echos podrian ser debidos a que la preparación física que tienen los jugadores estos últimos años es superior a la de hace 20 años, por eso vemos un mejor rendimiento en Lebron y Kobe.

# %% [markdown]
# A continuación realizaremos la media de puntos por partido de todas las temporadas

# %%
dataset_per_game_statsOrd.loc[:, ["Player","PTS"]].groupby("Player").mean()
# Out:
#                       PTS
# Player
# Kobe Bryant     24.497143
# Lebron James    28.051724
# Michael Jordan  31.596429

# %% [markdown]
# Como podemos observar, Michael Jordan aun siendo el que tenia un rendimiento menos estable es el que mejor media de puntos ha hecho en toda su carrera en partidos regulares anotando 31.59 puntos por partido. Por lo tanto, estadisticamente el mejor en este apartado sería Michael Jordan.

# %% [markdown]
# ### Rebotes por partido

# %% [markdown]
# Primero realizaremos una visualización general de los rebotes por partido de los 3 jugadores en toda su carrera.

# %%
g = sns.lineplot(x=dataset_per_game_stats["Season"], y= dataset_per_game_stats["TRB"], color="red", hue = dataset_per_game_stats["Player"], sort=True)
g.tick_params(axis="x", rotation=90)

# %% [markdown]
# Seguidamente realizaremos una visualizción para cada uno de los jugadores

# %%
g = sns.lineplot(x=MJ_RS["Season"], y= MJ_RS["TRB"], color="red", sort=True)
g.tick_params(axis="x", rotation=90)
text = plt.title("Micahel Jordan total rebounds per game")

# %%
g = sns.lineplot(x=KB_RS["Season"], y= KB_RS["TRB"], color="purple", sort=True)
g.tick_params(axis="x", rotation=90)
text = plt.title("Kobe Bryant total rebounds per game")

# %%
g = sns.lineplot(x=LB_RS["Season"], y= LB_RS["TRB"], color="yellow", sort=True)
g.tick_params(axis="x", rotation=90)
text = plt.title("Lebron James total rebounds per game")

# %% [markdown]
# Como podemos observar el rendimiento de los 3 jugadores en cuanto al total de rebotes por partido es bastante estable, pero sin duda el jugador que más destaca por encima del resto en esta categoria es Lebron James obtiendo una media de 8.5 rebotes por partido en su mejor temporada.
#
# Junto con Michael Jordan son los que obtienen los valores más altos en una temporada, 8 rebotes por partido Michael y 8.5 Lebron. No obstante, Kobe Bryant es el que se mantiene mas constante aun estando por debajo de ellos en cuanto a numeros.

# %%
dataset_per_game_statsOrd.loc[:, ["Player","TRB"]].groupby("Player").mean()
# Out:
#                      TRB
# Player
# Kobe Bryant     5.088571
# Lebron James    8.062069
# Michael Jordan  6.282143

# %% [markdown]
# Como era de esperar viendo los resultados de las graficas, el ganador para esta categoria es Lebron James siendo el que mas media de rebotes por partido obtiene en toda su carrera con un valor de 8.06 rebotes. Por lo tanto, podriamos decir que estadisticamente es el mejor de los 3.

# %% [markdown]
# ### Asistencias por partido

# %% [markdown]
# Primero realizaremos una visualización general de las asistencias por partido de los 3 jugadores en toda su carrera.

# %%
g = sns.lineplot(x=dataset_per_game_stats["Season"], y= dataset_per_game_stats["AST"], color="red", hue = dataset_per_game_stats["Player"], sort=True)
g.tick_params(axis="x", rotation=90)

# %% [markdown]
# Seguidamente realizaremos una visualizción para cada uno de los jugadores

# %%
g = sns.lineplot(x=MJ_RS["Season"], y= MJ_RS["AST"], color="red", sort=True)
g.tick_params(axis="x", rotation=90)
text = plt.title("Micahel Jordan total assists per game")

# %%
g = sns.lineplot(x=KB_RS["Season"], y= KB_RS["AST"], color="purple", sort=True)
g.tick_params(axis="x", rotation=90)
text = plt.title("Kobe Bryant total assists per game")

# %%
g = sns.lineplot(x=LB_RS["Season"], y= LB_RS["AST"], color="yellow", sort=True)
g.tick_params(axis="x", rotation=90)
text = plt.title("Lebron James total assists per game")

# %% [markdown]
# Observando los resultados de las graficas podemos decir que nuevamente Lebron James es el que obtiene los valores mas altos de media de asistencias por partido a diferencia de sus dos competidores. Kobe Bryant sigue siendo el que mantiene los resultados mas constantes en esta categoría sin sufrir tantos altibajos y para Michael Jordan podemos observar como al principio de su carrera obtenia unos resultados elevados comparables con los de Lebron pero a medida que pasan los años su rendimiento en esta categoria disminuye.

# %%
dataset_per_game_statsOrd.loc[:, ["Player","AST"]].groupby("Player").mean()
# Out:
#                      AST
# Player
# Kobe Bryant     4.628571
# Lebron James    7.168966
# Michael Jordan  5.482143

# %% [markdown]
# Como puede observarse, el jugador que obtiene un mayor numero de asistencias por partido durante toda su carrera es Lebron James con un total de 7.16 asistencias la cual cosa tiene sentido con los resultados de las graficas analizados anteriormente. Por lo tanto, estadisticamente es el mejor asistente de los 3

# %% [markdown]
# ### Partidos ganados

# %% [markdown]
# Visualizaremos los partidos ganados de cada jugador por temporada, esta vez utilizando el dataset allgames_stats.csv. Primero guardaremos los partidos ganados de cada jugador por temporada y seguidamente los visualizaremos en dos histogramas.

# %%
season = []
for i in range(dataset_allgames_stats.shape[0]):
    s = dataset_allgames_stats["Date"][i]
    season.append(int(s[0:4]))
dataset_allgames_stats["Season"] = season
dataset_allgames_stats["Season"] = pd.to_numeric(dataset_allgames_stats["Season"])

ganados = dataset_allgames_stats[dataset_allgames_stats.Result == 1]
MJ = ganados[ganados.Player == "Michael Jordan"]
KB = ganados[ganados.Player == "Kobe Bryant"]
LB = ganados[ganados.Player == "Lebron James"]

plt.figure()
sns.displot(ganados, x='Season', hue='Player',binwidth=0.5, edgecolor='black', 
linewidth=0.5)
plt.show()

plt.figure()
sns.displot(ganados, x='Season', hue='Player',binwidth=0.5, multiple="stack",edgecolor='black', 
linewidth=0.5)
plt.show()

# %% [markdown]
# A continuación guardaré el numero de victorias por temporada de cada jugador en toda su carrera en 3 diccionarios para posteriormente poder realizar la media de victorias por temporada.

# %%
winsMJ = {}
winsKB = {}
winsLB = {}


for i in range(dataset_allgames_stats.shape[0]):
    if dataset_allgames_stats["Player"][i] == "Michael Jordan":
        if dataset_allgames_stats["Season"][i] in winsMJ:
            pass
        else:
            winsMJ[dataset_allgames_stats["Season"][i]] = 0
            
    if dataset_allgames_stats["Player"][i] == "Kobe Bryant":
        if dataset_allgames_stats["Season"][i] in winsMJ:
            pass
        else:
            winsKB[dataset_allgames_stats["Season"][i]] = 0
            
    if dataset_allgames_stats["Player"][i] == "Lebron James":
        if dataset_allgames_stats["Season"][i] in winsMJ:
            pass
        else:
            winsLB[dataset_allgames_stats["Season"][i]] = 0

for i in range(dataset_allgames_stats.shape[0]):
    if dataset_allgames_stats["Result"][i] == 1:
        season = dataset_allgames_stats["Season"][i]
        if dataset_allgames_stats["Player"][i] == "Michael Jordan":
            winsMJ[season] = winsMJ[season] + 1
        if dataset_allgames_stats["Player"][i] == "Kobe Bryant":
            winsKB[season] = winsKB[season] + 1
        if dataset_allgames_stats["Player"][i] == "Lebron James":
            winsLB[season] = winsLB[season] + 1          
print(winsMJ)
print(winsLB)
print(winsKB)
# Out:
# {1984: 16, 1985: 26, 1986: 20, 1987: 41, 1988: 54, 1989: 60, 1990: 66, 1991: 80, 1992: 79, 1993: 50, 1995: 43, 1996: 89, 1997: 77, 1998: 57, 2001: 16, 2002: 28, 2003: 23}
# {2003: 10, 2004: 40, 2005: 42, 2006: 53, 2007: 56, 2008: 64, 2009: 76, 2010: 65, 2011: 50, 2012: 78, 2013: 79, 2014: 60, 2015: 67, 2016: 76, 2017: 63, 2018: 58, 2019: 8}
# {1996: 15, 1997: 57, 1998: 43, 1999: 48, 2000: 78, 2001: 59, 2002: 63, 2003: 63, 2004: 56, 2005: 28, 2006: 50, 2007: 42, 2008: 77, 2009: 81, 2010: 65, 2011: 41, 2012: 53, 2013: 29, 2014: 9, 2015: 7, 2016: 7}

# %%
print("Media de victorias por temporada")

num = 0
for i in winsMJ.items():
    num = num + i[1]
print("Michael Jordan: ",(num/len(winsMJ)))

num = 0
for i in winsKB.items():
    num = num + i[1]
print("Kobe Bryant: ",(num/len(winsKB)))

num = 0
for i in winsLB.items():
    num = num + i[1]
print("Lebron James: ",(num/len(winsLB)))
# Out:
# Media de victorias por temporada
# Michael Jordan:  48.529411764705884
# Kobe Bryant:  46.23809523809524
# Lebron James:  55.588235294117645

# %% [markdown]
# Como podemos observar al realizar las medias, Lebron James es el jugador de los tres que obtiene el mejor resultado en esta categoria con un valor de 55.58 victorias por temporada frente a las 48.52 y 46.23 de Michael Jordan y Kobe Bryant.
#
# Esta categoria no es tan decisiva para poder realizar un veredicto de quien es mejor ya que el ganar un partido no depende únicamente de un jugador sino de todo un equipo. No obstante, es un dato que nunca está demás compararlo para hacernos una idea de que jugador ganaba más partidos.

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# Habiendo comparado las tres estadisticas más importantes y relevantes que caracterizan a un jugador de baloncesto (puntos, rebotes y asistencias) para los tres jugadores, se ha llegado a una serie de conclusiones.
#
# Primero podríamos decir que estadísticamente Kobe Bryant lo tiene muy difícil para competir contra los otros 2, ya que aun teniendo muy buenos números, no se acercan a los de Michael Jordan y Lebron James. Sí es cierto que analizando los resultados podemos decir que Kobe Bryant es el que tiene un rendimiento mas constante de los tres.
#
# Ahora bien, analicemos los resultados de Michael Jordan y Lebron James para proclamar un vencedor. Michael Jordan es un gran jugador ofensivo y en esa faceta es mejor estadisticamente que Lebron James obteniendo un mejor ratio de puntos por partido pero en cuanto a asistencias y rebotes podriamos concluir que Lebron James es mejor reboteador y asistente ya que obtiene mejores resultados en esas dos categorias.
#
# Por lo tanto, al ser una pregunta difícil de contestar ya que habría que tener en cuenta una gran cantidad de datos y parametros ademas de que hay muchos aspectos que tambien hacen bueno a un jugador pero no pueden ser reflejados en números. Podriamos concluir que con los datos vistos y analizados en este apartado, estadísticamente el mejor jugador es **Lebron James**.

# %%
x = dataset_per_game_statsOrd.loc[:, ["Player","PTS"]].groupby("Player").mean()
y = dataset_per_game_statsOrd.loc[:, ["Player","TRB"]].groupby("Player").mean()
z = dataset_per_game_statsOrd.loc[:, ["Player","AST"]].groupby("Player").mean()
print(x)
print(y)
print(z)
# Out:
#                       PTS
# Player
# Kobe Bryant     24.497143
# Lebron James    28.051724
# Michael Jordan  31.596429
#                      TRB
# Player
# Kobe Bryant     5.088571
# Lebron James    8.062069
# Michael Jordan  6.282143
#                      AST
# Player
# Kobe Bryant     4.628571
# Lebron James    7.168966
# Michael Jordan  5.482143

# %% [markdown]
# ## 4. Preprocessing

# %% [markdown]
# En este apartado trataremos los datos. Es decir, normalizaremos y eliminaremos outliers y atributos innecesarios antes de realizar las predicciones.

# %% [markdown]
# ### 4.1. Tratamiento de valores nulos

# %% [markdown]
# Primero miraremos si nuestros datasets tienen muchos datos sin información

# %%
print("Dataset per_game_stats")
dataset_per_game_stats.isnull().sum()
# Out:
# Dataset per_game_stats
# Season    0
# Age       0
# Tm        0
# Lg        0
# Pos       0
# G         0
# GS        0
# MP        0
# FG        0
# FGA       0
# FG%       0
# 3P        0
# 3PA       0
# 3P%       0
# 2P        0
# 2PA       0
# 2P%       0
# eFG%      0
# FT        0
# FTA       0
# FT%       0
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS       0
# Player    0
# RSorPO    0
# dtype: int64

# %% [markdown]
# Como podemos observar para este dataset no existe ninguna celda con datos vacios

# %%
print("Dataset allgames_stats")
dataset_allgames_stats.isnull().sum()
# Out:
# Dataset allgames_stats
# G           0
# Date        0
# Tm          0
# X           0
# Opp         0
# Result      0
# GS          0
# MP          0
# FG          4
# FGA         7
# FG%        17
# 3P          0
# 3PA         0
# 3P%       504
# FT          1
# FTA         2
# FT%       135
# ORB         1
# DRB         2
# TRB         0
# AST         0
# STL        11
# BLK         1
# TOV         0
# PF          0
# PTS         9
# GmSc      219
# Player      0
# RSorPO      0
# Season      0
# dtype: int64

# %% [markdown]
# En canvio, para este dataset encontramos una serie de atributos que sí se encuentran vacios. Por lo tanto, es necesario una serie de transformaciones.

# %% [markdown]
# Para el resto de atributos, he decidido eliminar las muestras que contienen atributos nulos de menor cantidad. En canvio, para las muestras que contienen los atributos de mayor cantidad de valores nulos sustituiré esos valores nulos por la media.

# %%
dataset_allgames_stats["FG"].fillna(value=999, inplace=True)
dataset_allgames_stats["FGA"].fillna(value=999, inplace=True)
dataset_allgames_stats["FT"].fillna(value=999, inplace=True)
dataset_allgames_stats["FTA"].fillna(value=999, inplace=True)
dataset_allgames_stats["ORB"].fillna(value=999, inplace=True)
dataset_allgames_stats["DRB"].fillna(value=999, inplace=True)
dataset_allgames_stats["BLK"].fillna(value=999, inplace=True)
dataset_allgames_stats["PTS"].fillna(value=999, inplace=True)

filasElim = []
for i in range(dataset_allgames_stats.shape[0]):
    for x in dataset_allgames_stats.columns:
        if dataset_allgames_stats[x][i] == 999:
            filasElim.append(i)
dataset_allgames_stats = dataset_allgames_stats.drop(filasElim)

dataset_allgames_stats["FG%"].fillna(value=dataset_allgames_stats["FG%"].median(),inplace=True)
dataset_allgames_stats["3P%"].fillna(value=dataset_allgames_stats["3P%"].median(), inplace=True)
dataset_allgames_stats["FT%"].fillna(value=dataset_allgames_stats["FT%"].median(), inplace=True)
dataset_allgames_stats["STL"].fillna(value=dataset_allgames_stats["STL"].median(), inplace=True)
dataset_allgames_stats["GmSc"].fillna(value=dataset_allgames_stats["GmSc"].median(), inplace=True)

# %% [markdown]
# ### 4.2. Eliminación de atributos

# %% [markdown]
# Para los dos datasets hay una serie de atributos que por diferentes motivos no nos serán utiles, ya sea porque contienen datos de poca utilidad o porque son strings que unicamente nos servirian para analizar o visualizar datos en forma de histogramas pero no para hacer las predicciones.
#
# Por lo tanto, eliminaremos aquellos atributos que no nos vayan a ser utiles.

# %% [markdown]
# **per_game_stats.csv:**

# %% [markdown]
# Para este dataset eliminaremos los atributos que no nos seran útiles a la hora de hacer las predicciones. Estos serán: Season, Tm, Lg, Pos, G, GS, RSorPO y "Player"

# %%
dataset_per_game_statsPR = dataset_per_game_stats.drop(["Season", "Tm", "Lg", "Pos", "G", "GS", "RSorPO", "Player"], axis=1)

# %% [markdown]
# **allgames_stats.csv**

# %% [markdown]
# Para este dataset eliminaremos los atributos que no nos seran útiles a la hora de hacer las predicciones. Estos serán: G, Date, Tm, Opp, GS, RSorPO y Player

# %%
dataset_allgames_statsPR = dataset_allgames_stats.drop(["G", "Date", "Tm", "Opp", "GS", "RSorPO", "Player"], axis=1)

# %% [markdown]
# Por lo tanto los dos datasets nos quedan de la siguiente forma:

# %%
dataset_per_game_statsPR.head()
# Out:
#    Age    MP    FG   FGA   FG%   3P  3PA   3P%   2P   2PA  ...   FT%  ORB  \
# 0   19  39.5   7.9  18.9  0.42  0.8  2.7  0.30  7.1  16.1  ...  0.76  1.3
# 1   20  42.4   9.9  21.1  0.47  1.4  3.9  0.36  8.6  17.2  ...  0.75  1.4
# 2   21  42.5  11.1  23.1  0.48  1.6  4.8  0.33  9.5  18.3  ...  0.74  0.9
# 3   22  40.9   9.9  20.8  0.48  1.3  4.0  0.32  8.6  16.8  ...  0.70  1.1
# 4   23  40.4  10.6  21.9  0.48  1.5  4.8  0.31  9.1  17.1  ...  0.71  1.8
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  4.2  5.5  5.9  1.6  0.7  3.5  1.9  20.9
# 1  6.0  7.4  7.2  2.2  0.7  3.3  1.8  27.2
# 2  6.1  7.0  6.6  1.6  0.8  3.3  2.3  31.4
# 3  5.7  6.7  6.0  1.6  0.7  3.2  2.2  27.3
# 4  6.1  7.9  7.2  1.8  1.1  3.4  2.2  30.0
#
# [5 rows x 24 columns]

# %%
dataset_allgames_statsPR.head()
# Out:
#    X  Result  MP   FG  FGA   FG%  3P  3PA   3P%   FT  ...  TRB  AST  STL  BLK  \
# 0  1       1   6  0.0  1.0  0.00   0    0  0.29  0.0  ...    1    0  0.0  1.0
# 1  0       1   3  0.0  1.0  0.00   0    0  0.29  1.0  ...    0    0  0.0  0.0
# 2  0       0   7  2.0  3.0  0.67   1    2  0.50  0.0  ...    0    0  0.0  0.0
# 3  0       0  17  3.0  8.0  0.38   2    3  0.67  2.0  ...    3    0  0.0  1.0
# 4  1       1   8  0.0  3.0  0.00   0    0  0.29  2.0  ...    3    1  0.0  0.0
#
#    TOV  PF   PTS  GmSc       Player  Season
# 0    1   1   0.0  -1.1  Kobe Bryant    1996
# 1    1   0   1.0  -1.1  Kobe Bryant    1996
# 2    3   0   5.0   0.7  Kobe Bryant    1996
# 3    0   3  10.0   5.2  Kobe Bryant    1996
# 4    0   0   2.0   1.9  Kobe Bryant    1996
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 4.3 Outliers removal

# %% [markdown]
# A continuación veremos si en los datasets existen algun tipo de outlier (valor extremo o anormal) que pueda afectar a la hora de realizar las predicciones.

# %% [markdown]
# **dataset per_game_stats.csv**

# %% [markdown]
# Comprobaremos la existencia de outliers para los atributos que mas correlacion tienen con nuestro atributo target además de también comprobarlo para el atributo target ya que son los atributos que utilizaremos para la regresión lineal. Tambíen visualizaremos si siguen una distribución normal.

# %%
# FG (0.97), FGA (0.92), 2P (0.92), FTA (0.79), FT (0.51), 2PA (0.55) y STL (0.64)
sns.displot(dataset_per_game_statsPR['PTS'], binwidth=1, multiple="stack")
plt.show()
sns.boxplot(dataset_per_game_statsPR['PTS'])
plt.show()
sns.displot(dataset_per_game_statsPR['FG'], binwidth=1, multiple="stack")
plt.show()
sns.boxplot(dataset_per_game_statsPR['FG'])
plt.show()
sns.displot(dataset_per_game_statsPR['FGA'], binwidth=1, multiple="stack")
plt.show()
sns.boxplot(dataset_per_game_statsPR['FGA'])
plt.show()
sns.displot(dataset_per_game_statsPR['2P'], binwidth=1, multiple="stack")
plt.show()
sns.boxplot(dataset_per_game_statsPR['2P'])
plt.show()
sns.displot(dataset_per_game_statsPR['FTA'], binwidth=1, multiple="stack")
plt.show()
sns.boxplot(dataset_per_game_statsPR['FTA'])
plt.show()
sns.displot(dataset_per_game_statsPR['FT'], binwidth=1, multiple="stack")
plt.show()
sns.boxplot(dataset_per_game_statsPR['FT'])
plt.show()
sns.displot(dataset_per_game_statsPR['2PA'], binwidth=1, multiple="stack")
plt.show()
sns.boxplot(dataset_per_game_statsPR['2PA'])
plt.show()
sns.displot(dataset_per_game_statsPR['STL'], binwidth=1, multiple="stack")
plt.show()
sns.boxplot(dataset_per_game_statsPR['STL'])
plt.show()

# %% [markdown]
# **dataset allgames_stats.csv**

# %%
# FG, FGA, GmSc, FT y PTS
sns.displot(dataset_allgames_statsPR['PTS'], binwidth=1, multiple="stack")
plt.show()
sns.boxplot(dataset_allgames_statsPR['PTS'])
plt.show()
sns.displot(dataset_allgames_statsPR['FG'], binwidth=1, multiple="stack")
plt.show()
sns.boxplot(dataset_allgames_statsPR['FG'])
plt.show()
sns.displot(dataset_allgames_statsPR['FGA'], binwidth=1, multiple="stack")
plt.show()
sns.boxplot(dataset_allgames_statsPR['FGA'])
plt.show()
sns.displot(dataset_allgames_statsPR['GmSc'], binwidth=1, multiple="stack")
plt.show()
sns.boxplot(dataset_allgames_statsPR['GmSc'])
plt.show()
sns.displot(dataset_allgames_statsPR['FT'], binwidth=1, multiple="stack")
plt.show()
sns.boxplot(dataset_allgames_statsPR['FT'])
plt.show()

# %% [markdown]
# Como podemos ver, no tenemos datos anormales o extremos muy claros por lo tanto se ha decidido no eliminarlos ya que no afectaran tanto al modelo.

# %% [markdown]
# ### 4.5 Normalización

# %% [markdown]
# El siguiente paso es muy necesario, normalizaremos los datos del dataset y así de esta forma podremos obtener los mejores resultados y evitar inexactitudes de datos o ineficiència de operaciones.

# %% [markdown]
# **dataset per_game_stats.csv**

# %%
scaler = StandardScaler()
standardized = scaler.fit_transform(dataset_per_game_statsPR)
dataset_per_game_statsNORM = pd.DataFrame(standardized, columns=dataset_per_game_statsPR.columns)

print(dataset_per_game_statsNORM)
# Out:
#          Age        MP        FG       FGA       FG%        3P       3PA  \
# 0  -1.629225  0.138423 -0.920691 -0.500513 -1.191527 -0.631546 -0.502652
# 1  -1.428302  0.669047 -0.044749  0.012418 -0.072951  0.396812  0.245229
# 2  -1.227379  0.687344  0.480816  0.478719  0.150765  0.739598  0.806141
# 3  -1.026455  0.394586 -0.044749 -0.057527  0.150765  0.225419  0.307553
# 4  -0.825532  0.303100  0.261831  0.198938  0.150765  0.568205  0.806141
# ..       ...       ...       ...       ...       ...       ...       ...
# 87  0.380007  0.431181  0.261831  0.222253  0.150765  0.568205  0.930788
# 88  0.580930  0.394586  0.218033  0.455404 -0.296666  0.739598  0.681494
# 89  0.781853  0.248208  0.086642  0.268883 -0.296666  1.596562  1.367052
# 90  0.982776 -0.611768 -0.745503 -0.570458 -0.520381  0.054026  0.369876
# 91  1.183700  0.175018  0.437019  0.945019 -0.744096  0.396812  0.930788
#
#          3P%        2P       2PA  ...       FT%       ORB       DRB       TRB  \
# ...

# %% [markdown]
# **dataset allgames_stats.csv**

# %%
scaler = StandardScaler()
standardized = scaler.fit_transform(dataset_allgames_statsPR)
dataset_allgames_statsNORM = pd.DataFrame(standardized, columns=dataset_allgames_statsPR.columns)

# %% [markdown]
# ## 5. Regresión lineal: Prediccion atributo PTS (Objetivo 2)

# %% [markdown]
# Una vez tenemos todos los datos procesados y normalizados pasaremos a realizar las predicciones del atributo PTS, para ello utilizaremos varios modelos de regresion lineal y comprobaremos cuales son más optimos comparando los resultados de Score, Cross Val Score y MSE .

# %%
plt.figure()
plt.scatter(dataset_per_game_statsPR['FG'], dataset_per_game_statsPR['PTS'], color='tab:blue')
plt.title("Dataset per_game_stats.csv")
plt.ylabel("PTS")
plt.xlabel("FG")
plt.show()

plt.figure()
plt.scatter(dataset_allgames_statsPR['FG'], dataset_allgames_statsPR['PTS'], color='tab:blue')
plt.title("Dataset allgames_stats.csv")
plt.ylabel("PTS")
plt.xlabel("FG")
plt.show()

# %% [markdown]
# En las dos graficas podemos observar como los puntos (PTS) se distribuyen segun las canastas (FG) debido a la gran correlación de los atributos. Generalmente, a más canastas (FG) más puntos (PTS)

# %% [markdown]
# Una primera hipótesis que podemos pensar es que obtendremos mejores resultados para los modelos que se realizen para el dataset de per_game_stats.csv, no por la diferéncia en la cantidad de datos, sino porque este primero contiene medias lo que quiere decir que los puntos de las muestras seran mas semejantes entre ellos, en cambio el dataset de allgames al contener las muestras de todos los partidos conllevará a que los puntos sean más diferentes entre muestras.

# %%
resultados = {'Dataset:': [], 'Model': [], 'Score': [], 'Cross Val Score': [], 'MSE': [], 'Detalles' : []}
resultados = pd.DataFrame(data=resultados)

# %% [markdown]
# ### 5.1. Regresión lineal Univariable

# %% [markdown]
# Comenzaremos comprobando el modelo de regresión lineal más básico, utilizando el atributo con más correlación (FG) como entrada de nuestro modelo (x) y los puntos como la salida (y) ya que es el atributo que queremos predecir.

# %% [markdown]
# Para tal de validar el rendimiento de nuestro modelo (cross validation score) utilizaremos el metodo KFold donde los datos de la muestra son divididos en K subconjuntos, uno de los subconjuntos se utiliza como datos de prueba y el resto (K-1) como datos de entrenamiento. El cross validation se repite durante k iteraciones, con cada uno de los posibles subconjuntos de datos de prueba.
#
# Es necesario encontrar con que K se obtendran los mejores resultados por lo tanto:

# %%
folds = range(2,11)

def evaluatemodel(cv, standar):

    x = dataset_per_game_statsNORM[["FG"]]
    y = dataset_per_game_statsNORM[["PTS"]]
    lab = preprocessing.LabelEncoder()
    y_transformed = lab.fit_transform(y)
    
    linReg = LinearRegression()
    scores = cross_val_score(linReg, x, y, cv=cv, n_jobs=-1)
    return mean(scores), scores.min(), scores.max()

for k in folds:
    cv = KFold(n_splits=k, shuffle=True, random_state=10)
    k_mean, k_min, k_max = evaluatemodel(cv, dataset_per_game_statsNORM)
    print('-> folds=%d, accuracy=%.3f (%.3f,%.3f)' % (k, k_mean, k_min, k_max))

print("")
    
def evaluatemodel2(cv, standar):

    x = dataset_allgames_statsNORM[["FG"]]
    y = dataset_allgames_statsNORM[["PTS"]]
    lab = preprocessing.LabelEncoder()
    y_transformed = lab.fit_transform(y)
    
    linReg = LinearRegression()
    scores = cross_val_score(linReg, x, y, cv=cv, n_jobs=-1)
    return mean(scores), scores.min(), scores.max()

for k in folds:
    cv = KFold(n_splits=k, shuffle=True, random_state=10)
    k_mean, k_min, k_max = evaluatemodel(cv, dataset_allgames_statsNORM)
    print('-> folds=%d, accuracy=%.3f (%.3f,%.3f)' % (k, k_mean, k_min, k_max))

    
    
# k = 2, k = 5
# Out:
# -> folds=2, accuracy=0.937 (0.936,0.937)
# -> folds=3, accuracy=0.932 (0.915,0.944)
# -> folds=4, accuracy=0.917 (0.873,0.948)
# -> folds=5, accuracy=0.918 (0.862,0.969)
# -> folds=6, accuracy=0.901 (0.767,0.961)
# -> folds=7, accuracy=0.899 (0.772,0.975)
# -> folds=8, accuracy=0.914 (0.768,0.961)
# -> folds=9, accuracy=0.911 (0.794,0.957)
# -> folds=10, accuracy=0.892 (0.693,0.979)
#
# -> folds=2, accuracy=0.937 (0.936,0.937)
# -> folds=3, accuracy=0.932 (0.915,0.944)
# -> folds=4, accuracy=0.917 (0.873,0.948)
# -> folds=5, accuracy=0.918 (0.862,0.969)
# -> folds=6, accuracy=0.901 (0.767,0.961)
# -> folds=7, accuracy=0.899 (0.772,0.975)
# -> folds=8, accuracy=0.914 (0.768,0.961)
# -> folds=9, accuracy=0.911 (0.794,0.957)
# -> folds=10, accuracy=0.892 (0.693,0.979)

# %% [markdown]
# Normalmente se acostuma a escoger k = 5 o k = 10 pero como podemos ver la K con mejor accuracy para los dos datasets es k = 2 con un accuracy de 0.937, por lo tanto utilizaremos esa.

# %%
# Regresion lineal univariada

def mse(v1, v2):
    return ((v1 - v2)**2).mean()

k = 2
x = dataset_per_game_statsNORM[["FG"]]
y = dataset_per_game_statsNORM[["PTS"]]

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size=0.20, random_state=80)

print("LINEAR REGRESSION per_game_stats.csv", "\n")

lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)

kfold = KFold(n_splits=k, shuffle=True, random_state=7)

score = lin_reg.score(x_test, y_test)
csvScore = np.mean(cross_val_score(lin_reg, x_train, y_train, cv=kfold))
mseScore = mean_squared_error(lin_reg.predict(x_test),y_test)

print("Linear Regression Score: ", score)
print("Linear Regression Cross Val Score", csvScore)
print("Linear Regression MSE: ", mseScore)

resultados = resultados.append({'Dataset:': "per_game_stats.csv", 'Model': "Linear Regresion Univariada", 'Score': score, 'Cross Val Score': csvScore, 'MSE': mseScore, 'Detalles': "X: FG / Y: PTS"}, ignore_index=True)


atribut1 = x_test["FG"].values.reshape(x_test.shape[0], 1) 
predicted = lin_reg.predict(atribut1)

plt.figure()
ax = plt.scatter(x_test["FG"], y_test)
lin = plt.plot(atribut1[:,0], predicted, 'r')
# Out:
# LINEAR REGRESSION per_game_stats.csv
#
# Linear Regression Score:  0.9708726104002563
# Linear Regression Cross Val Score 0.8851372213861624
# Linear Regression MSE:  0.05219497055423168

# %%
resultados
# Out:
#              Dataset:                        Model     Score  Cross Val Score  \
# 0  per_game_stats.csv  Linear Regresion Univariada  0.970873         0.885137
#
#         MSE        Detalles
# 0  0.052195  X: FG / Y: PTS

# %% [markdown]
# Como podemos observar, era de esperar que utilizando como variable independiente el FG obtengamos muy buenos valores de score y cross validation score ademas de un mse bajo. Esto significa que el modelo se ajusta bastante bien a los datos usando este atributo ya que es el que más correlación tiene con los puntos por partido. Estos resultados tienen sentido ya que los puntos por partido de un jugador van a depender totalmente del numero de canastas que realice por partido.

# %%
def mse(v1, v2):
    return ((v1 - v2)**2).mean()

k = 2
x = dataset_allgames_statsNORM[["FG"]]
y = dataset_allgames_statsNORM[["PTS"]]

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size=0.20, random_state=80)

print("LINEAR REGRESSION allgames_stats.csv", "\n")

lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)

kfold = KFold(n_splits=k, shuffle=True, random_state=7)

score = lin_reg.score(x_test, y_test)
csvScore = np.mean(cross_val_score(lin_reg, x_train, y_train, cv=kfold))
mseScore = mean_squared_error(lin_reg.predict(x_test),y_test)

print("Linear Regression Score: ", score)
print("Linear Regression Cross Val Score", csvScore)
print("Linear Regression MSE: ", mseScore)

resultados = resultados.append({'Dataset:': "allgames_stats.csv", 'Model': "Linear Regresion Univariada", 'Score': score, 'Cross Val Score': csvScore, 'MSE': mseScore, 'Detalles': "X: FG / Y: PTS" }, ignore_index=True)

atribut1 = x_test["FG"].values.reshape(x_test.shape[0], 1) 
predicted = lin_reg.predict(atribut1)

plt.figure()
ax = plt.scatter(x_test["FG"], y_test)
lin = plt.plot(atribut1[:,0], predicted, 'r')
# Out:
# LINEAR REGRESSION allgames_stats.csv
#
# Linear Regression Score:  0.8406015328011767
# Linear Regression Cross Val Score 0.8343051569094061
# Linear Regression MSE:  0.17350646694127045

# %%
resultados
# Out:
#              Dataset:                        Model     Score  Cross Val Score  \
# 0  per_game_stats.csv  Linear Regresion Univariada  0.970873         0.885137
# 1  allgames_stats.csv  Linear Regresion Univariada  0.840602         0.834305
#
#         MSE        Detalles
# 0  0.052195  X: FG / Y: PTS
# 1  0.173506  X: FG / Y: PTS

# %% [markdown]
# Para este modelo obtenemos unos resultados más bajos y un error más grande que el anterior. Esto no es debido a que contiene miles de muestras más sino a que contiene la puntuación que ha realizado cada uno de los 3 jugadores en todos y cada uno de sus partidos lo que nos hace pensar que es evidente que serán más diferentes entre ellas a diferencia del anterior dataset donde todas las puntuaciones son la media de todos los partidos de la temporada la cual cosa hace que sean más semejantes entre ellas. Por lo tanto, el resultado tiene sentido.

# %% [markdown]
# ### 5.2. Regresión lineal Multivariable

# %% [markdown]
# Para este modelo seleccionaremos los atributos predictores que mas correlación tienen con el atributo a predecir, ya que son los que más importancia tienen y mas influyen al target puntos por partido.
#
# Para el dataset per_game_stats.csv escogeremos:
#
#     - Predictores(x): FG, FGA, 2P y FTA
#     - Target(y): PTS
#
# Para el dataset allgames_stats.csv escogeremos:
#
#     - Predictores(x): FG, FGA, GmSc y FT
#     - Target(y): PTS

# %%
# Regresion lineal multivariada

def mse(v1, v2):
    return ((v1 - v2)**2).mean()

k = 2
x = dataset_per_game_statsNORM[["FG", "FGA", "2P", "FTA"]]
y = dataset_per_game_statsNORM[["PTS"]]

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size=0.20, random_state=80)

print("LINEAR REGRESSION MULTIVARIABLE per_game_stats.csv", "\n")

lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)

kfold = KFold(n_splits=k, shuffle=True, random_state=7)

score = lin_reg.score(x_test, y_test)
csvScore = np.mean(cross_val_score(lin_reg, x_train, y_train, cv=kfold))
mseScore = mean_squared_error(lin_reg.predict(x_test),y_test)

print("Linear Regression Score: ", score)
print("Linear Regression Cross Val Score", csvScore)
print("Linear Regression MSE: ", mseScore)

resultados = resultados.append({'Dataset:': "per_game_stats.csv", 'Model': "Linear Regresion Multivariada", 'Score': score, 'Cross Val Score': csvScore, 'MSE': mseScore, 'Detalles': "X: FG, FGA, 2P, FTA / Y: PTS" }, ignore_index=True)


predictores = ["FG", "FGA", "2P", "FTA"]

for i in predictores:
    x_tr = x_train[i].values.reshape(x_train.shape[0], 1) 
    x_te = x_test[i].values.reshape(x_test.shape[0], 1) 
    regr = LinearRegression()
    regr.fit(x_tr, y_train)
    predicted = regr.predict(x_te)
    
    plt.figure()
    plt.title(i)
    ax = plt.scatter(x_te, y_test)
    plt.plot(x_te, predicted, 'r')
# Out:
# LINEAR REGRESSION MULTIVARIABLE per_game_stats.csv
#
# Linear Regression Score:  0.9965536468870321
# Linear Regression Cross Val Score 0.9925599580516995
# Linear Regression MSE:  0.006175709588902891

# %%
resultados
# Out:
#              Dataset:                          Model     Score  \
# 0  per_game_stats.csv    Linear Regresion Univariada  0.970873
# 1  allgames_stats.csv    Linear Regresion Univariada  0.840602
# 2  per_game_stats.csv  Linear Regresion Multivariada  0.996554
#
#    Cross Val Score       MSE                      Detalles
# 0         0.885137  0.052195                X: FG / Y: PTS
# 1         0.834305  0.173506                X: FG / Y: PTS
# 2         0.992560  0.006176  X: FG, FGA, 2P, FTA / Y: PTS

# %% [markdown]
# Para el primer modelo obtenemos unos resultados de ambas scores casi perfectos de 0.99 acompañadas de un error muy pequeño. De momento son los mejores resultados obtenidos y es sin duda el modelo que mejor se ajusta a los datos. Ahora bien, comprobemos si estos resultados tienen sentido.
#
# Estamos tratando con un dataset que contiene todas las estadisticas medias y un total de 94 muestras. Además, estamos usando como variables independientes el FG, FGA, 2P y FTA. Dichas variables son las que más correlacion tienen con nuestra variable dependiente y hacen referencia a los tiros totales encestados, los intentos de tiro totales, los tiros de 2 puntos encestados y los intentos de tiros libres realizados.
#
# Tiene sentido que obtengamos este resultado porque la puntuación de un jugador se ve influida totalmente por los tiros totales que realiza/encesta y los tiros de 2 puntos que encesta ya que son los que mayormente se realizan con existo en un partido de baloncesto.

# %%
def mse(v1, v2):
    return ((v1 - v2)**2).mean()

k = 2
x = dataset_allgames_statsNORM[["FG","FGA", "GmSc", "FT"]]
y = dataset_allgames_statsNORM[["PTS"]]

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size=0.20, random_state=80)

print("LINEAR REGRESSION MULTIVARIABLE allgames_stats.csv", "\n")

lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)

kfold = KFold(n_splits=k, shuffle=True, random_state=7)

score = lin_reg.score(x_test, y_test)
csvScore = np.mean(cross_val_score(lin_reg, x_train, y_train, cv=kfold))
mseScore = mean_squared_error(lin_reg.predict(x_test),y_test)

print("Linear Regression Score: ", score)
print("Linear Regression Cross Val Score", csvScore)
print("Linear Regression MSE: ", mseScore)

resultados = resultados.append({'Dataset:': "allgames_stats.csv", 'Model': "Linear Regresion Multivariada", 'Score': score, 'Cross Val Score': csvScore, 'MSE': mseScore, 'Detalles': "X: FG, FGA, GmSc, FT / Y: PTS" }, ignore_index=True)

predictores = ["FG","FGA","GmSc","FT"]

for i in predictores:
    x_tr = x_train[i].values.reshape(x_train.shape[0], 1) 
    x_te = x_test[i].values.reshape(x_test.shape[0], 1) 
    regr = LinearRegression()
    regr.fit(x_tr, y_train)
    predicted = regr.predict(x_te)
    
    plt.figure()
    plt.title(i)
    ax = plt.scatter(x_te, y_test)
    plt.plot(x_te, predicted, 'r')
# Out:
# LINEAR REGRESSION MULTIVARIABLE allgames_stats.csv
#
# Linear Regression Score:  0.982120767625803
# Linear Regression Cross Val Score 0.9825068103001999
# Linear Regression MSE:  0.019461683009783622

# %%
resultados
# Out:
#              Dataset:                          Model     Score  \
# 0  per_game_stats.csv    Linear Regresion Univariada  0.970873
# 1  allgames_stats.csv    Linear Regresion Univariada  0.840602
# 2  per_game_stats.csv  Linear Regresion Multivariada  0.996554
# 3  allgames_stats.csv  Linear Regresion Multivariada  0.982121
#
#    Cross Val Score       MSE                       Detalles
# 0         0.885137  0.052195                 X: FG / Y: PTS
# 1         0.834305  0.173506                 X: FG / Y: PTS
# 2         0.992560  0.006176   X: FG, FGA, 2P, FTA / Y: PTS
# 3         0.982507  0.019462  X: FG, FGA, GmSc, FT / Y: PTS

# %% [markdown]
# Para este segundo modelo, al igual que en el caso anterior obtenemos unos resultados de scores y error casi perfectos convirtiendolo en el segundo modelo que mejor se ajusta a los datos. Si lo comparamos con el anterior, es escasamente un poco menos preciso a la hora de realizar las predicciones esto es debido a que este dataset contiene más cantidad de puntuaciones diferentes y estamos operando con dos variable independientes nuevas, el GmSc que es una puntuación que hace referencia al rendimiento del jugador en el partido y el FT que hace referencia a los tiros libres encestados.
#
# Estos dos atributos nuevos tienen escasamente un poco menos de correlación con el atributo target en comparación con los anteriores que han sido substituidos (2P y FTA) por eso obtenemos unos scores un poco mas bajos. Tiene sentido ya que por ejemplo la puntuación de un jugador en un partido no va a depender siempre de la puntuación de su rendimiento (GmSc) ya que puede haber rendido extraordinariamente bien como defensor y por ello obtener tan buena puntuación pero no haber realizado ningún punto.

# %% [markdown]
# ### 5.3. Comprobación del modelo

# %% [markdown]
# Ahora pondremos a prueba el modelo utilizando diferentes atributos con menos información o que no influyan tan directamente en la puntuación de un jugador y así de esta forma podremos verificar el comportamiendo del modelo y ver como varía.

# %% [markdown]
# Cogeremos el modelo que mejor resultado nos ha dado y quitaremos las variables independientes que más influyen a la puntuación, de este modo nos quedamos unicamente con FGA y FTA (intentos de canasta y intentos de tiro libre).

# %%
def mse(v1, v2):
    return ((v1 - v2)**2).mean()

k = 2
x = dataset_per_game_statsNORM[["FGA", "FTA"]]
y = dataset_per_game_statsNORM[["PTS"]]

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size=0.20, random_state=80)

print("LINEAR REGRESSION MULTIVARIABLE per_game_stats.csv", "\n")

lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)

kfold = KFold(n_splits=k, shuffle=True, random_state=7)

score = lin_reg.score(x_test, y_test)
csvScore = np.mean(cross_val_score(lin_reg, x_train, y_train, cv=kfold))
mseScore = mean_squared_error(lin_reg.predict(x_test),y_test)

print("Linear Regression Score: ", score)
print("Linear Regression Cross Val Score", csvScore)
print("Linear Regression MSE: ", mseScore)

resultados = resultados.append({'Dataset:': "per_game_stats.csv", 'Model': "Linear Regresion Multivariada", 'Score': score, 'Cross Val Score': csvScore, 'MSE': mseScore, 'Detalles': "X: FGA, FTA / Y: PTS" }, ignore_index=True)


predictores = ["FGA","FTA"]

for i in predictores:
    x_tr = x_train[i].values.reshape(x_train.shape[0], 1) 
    x_te = x_test[i].values.reshape(x_test.shape[0], 1) 
    regr = LinearRegression()
    regr.fit(x_tr, y_train)
    predicted = regr.predict(x_te)
    
    plt.figure()
    plt.title(i)
    ax = plt.scatter(x_te, y_test)
    plt.plot(x_te, predicted, 'r')
# Out:
# LINEAR REGRESSION MULTIVARIABLE per_game_stats.csv
#
# Linear Regression Score:  0.9479700708333197
# Linear Regression Cross Val Score 0.8671512226679791
# Linear Regression MSE:  0.09323529015513055

# %%
resultados
# Out:
#              Dataset:                          Model     Score  \
# 0  per_game_stats.csv    Linear Regresion Univariada  0.970873
# 1  allgames_stats.csv    Linear Regresion Univariada  0.840602
# 2  per_game_stats.csv  Linear Regresion Multivariada  0.996554
# 3  allgames_stats.csv  Linear Regresion Multivariada  0.982121
# 4  per_game_stats.csv  Linear Regresion Multivariada  0.947970
#
#    Cross Val Score       MSE                       Detalles
# 0         0.885137  0.052195                 X: FG / Y: PTS
# 1         0.834305  0.173506                 X: FG / Y: PTS
# 2         0.992560  0.006176   X: FG, FGA, 2P, FTA / Y: PTS
# 3         0.982507  0.019462  X: FG, FGA, GmSc, FT / Y: PTS
# 4         0.867151  0.093235           X: FGA, FTA / Y: PTS

# %% [markdown]
# Como podemos ver las puntuaciones bajan y el error sube, concretamente la Score baja un 5%. Estos es debido a que los intentos de tiro influyen en gran medida a la puntuación pero no es un factor determinante ya que puede haber realizado 100 intentos y haber encestado 0 y por lo tanto haber optenido 0 puntos. Si que es verdad que generalmente influyen porque contra mas se intenta mas posibilidades hay de encestar pero no es tan determinante como los tiros con éxito. Dicha afirmación se puede ver reflejada tambien con la correlacion que tienen la FTA y FGA con la puntuación. Por lo tanto, tiene sentido que disminuya un poco pero no notoriamente.

# %% [markdown]
# Ahora intentaremos realizar la predicción en base a la puntuación de rendimiento del jugador en el partido (GmSc) para analizar que resultados obtenemos y como se comporta el modelo

# %%
def mse(v1, v2):
    return ((v1 - v2)**2).mean()

k = 2
x = dataset_allgames_statsNORM[["GmSc"]]
y = dataset_allgames_statsNORM[["PTS"]]

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size=0.20, random_state=80)

print("LINEAR REGRESSION UNIVARIADA allgames_stats.csv", "\n")

lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)

kfold = KFold(n_splits=k, shuffle=True, random_state=7)

score = lin_reg.score(x_test, y_test)
csvScore = np.mean(cross_val_score(lin_reg, x_train, y_train, cv=kfold))
mseScore = mean_squared_error(lin_reg.predict(x_test),y_test)

print("Linear Regression Score: ", score)
print("Linear Regression Cross Val Score", csvScore)
print("Linear Regression MSE: ", mseScore)

resultados = resultados.append({'Dataset:': "allgames_stats.csv", 'Model': "Linear Regresion Univariada", 'Score': score, 'Cross Val Score': csvScore, 'MSE': mseScore, 'Detalles': "X: GmSc / Y: PTS" }, ignore_index=True)

atribut1 = x_test["GmSc"].values.reshape(x_test.shape[0], 1) 
predicted = lin_reg.predict(atribut1)

plt.figure()
ax = plt.scatter(x_test["GmSc"], y_test)
lin = plt.plot(atribut1[:,0], predicted, 'r')
# Out:
# LINEAR REGRESSION UNIVARIADA allgames_stats.csv
#
# Linear Regression Score:  0.6958809387542875
# Linear Regression Cross Val Score 0.67376324576891
# Linear Regression MSE:  0.33103595519787365

# %%
resultados
# Out:
#              Dataset:                          Model     Score  \
# 0  per_game_stats.csv    Linear Regresion Univariada  0.970873
# 1  allgames_stats.csv    Linear Regresion Univariada  0.840602
# 2  per_game_stats.csv  Linear Regresion Multivariada  0.996554
# 3  allgames_stats.csv  Linear Regresion Multivariada  0.982121
# 4  per_game_stats.csv  Linear Regresion Multivariada  0.947970
# 5  allgames_stats.csv    Linear Regresion Univariada  0.695881
#
#    Cross Val Score       MSE                       Detalles
# 0         0.885137  0.052195                 X: FG / Y: PTS
# 1         0.834305  0.173506                 X: FG / Y: PTS
# 2         0.992560  0.006176   X: FG, FGA, 2P, FTA / Y: PTS
# 3         0.982507  0.019462  X: FG, FGA, GmSc, FT / Y: PTS
# 4         0.867151  0.093235           X: FGA, FTA / Y: PTS
# 5         0.673763  0.331036               X: GmSc / Y: PTS

# %% [markdown]
# A priori se puede pensar que obtendriamos buenos resultados al tratarse del rendimiento, pero como podemos ver, en este caso hemos obtenido peores resultados en general. Como se ha comentado anteriormente, la puntuación no va a depender completamente del rendimiento, los tres jugadores con los que estamos trabajando jugaban en posiciones distintas y muy versátiles por este motivo no siempre un buen rendimiento iba acompañado de un gran numero de puntos en un partido. El modelo es más dificil que se ajuste a los datos ya que pueden haber muestras donde el jugador ha obtenido una gran nota de rendimiento porque ha defendido excelentemente pero ha anotado 0 puntos, si todas las muestras del dataset fueran de partidos donde los jugadores jugaban en posiciones únicamente ofensivas donde su rendimiento se ve más reflejado por la cantidad de puntos realizados, entonces sí que el modelo se ajustaría perfectamente.

# %% [markdown]
# Ahora comprobaremos el comportamiento del modelo si tomamos únicamente como variables independientes las estadísticas referentes a los 2 puntos y 3 puntos.

# %%
def mse(v1, v2):
    return ((v1 - v2)**2).mean()

k = 2
x = dataset_per_game_statsNORM[["2P", "3P", "3PA", "3P%", "2PA", "2P%"]]
y = dataset_per_game_statsNORM[["PTS"]]

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size=0.20, random_state=80)

print("LINEAR REGRESSION MULTIVARIABLE per_game_stats.csv", "\n")

lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)

kfold = KFold(n_splits=k, shuffle=True, random_state=7)

score = lin_reg.score(x_test, y_test)
csvScore = np.mean(cross_val_score(lin_reg, x_train, y_train, cv=kfold))
mseScore = mean_squared_error(lin_reg.predict(x_test),y_test)

print("Linear Regression Score: ", score)
print("Linear Regression Cross Val Score", csvScore)
print("Linear Regression MSE: ", mseScore)

resultados = resultados.append({'Dataset:': "per_game_stats.csv", 'Model': "Linear Regresion Multivariada", 'Score': score, 'Cross Val Score': csvScore, 'MSE': mseScore, 'Detalles': "X: 2P, 2PA, 2P%, 3P, 3PA, 3P% / Y: PTS" }, ignore_index=True)

predictores = ["2P", "3P", "3PA", "3P%", "2PA", "2P%"]

for i in predictores:
    x_tr = x_train[i].values.reshape(x_train.shape[0], 1) 
    x_te = x_test[i].values.reshape(x_test.shape[0], 1) 
    regr = LinearRegression()
    regr.fit(x_tr, y_train)
    predicted = regr.predict(x_te)
    
    plt.figure()
    plt.title(i)
    ax = plt.scatter(x_te, y_test)
    plt.plot(x_te, predicted, 'r')
# Out:
# LINEAR REGRESSION MULTIVARIABLE per_game_stats.csv
#
# Linear Regression Score:  0.9563569256817885
# Linear Regression Cross Val Score 0.900494122559282
# Linear Regression MSE:  0.07820642392736885

# %%
resultados
# Out:
#              Dataset:                          Model     Score  \
# 0  per_game_stats.csv    Linear Regresion Univariada  0.970873
# 1  allgames_stats.csv    Linear Regresion Univariada  0.840602
# 2  per_game_stats.csv  Linear Regresion Multivariada  0.996554
# 3  allgames_stats.csv  Linear Regresion Multivariada  0.982121
# 4  per_game_stats.csv  Linear Regresion Multivariada  0.947970
# 5  allgames_stats.csv    Linear Regresion Univariada  0.695881
# 6  per_game_stats.csv  Linear Regresion Multivariada  0.956357
#
#    Cross Val Score       MSE                                Detalles
# 0         0.885137  0.052195                          X: FG / Y: PTS
# 1         0.834305  0.173506                          X: FG / Y: PTS
# 2         0.992560  0.006176            X: FG, FGA, 2P, FTA / Y: PTS
# 3         0.982507  0.019462           X: FG, FGA, GmSc, FT / Y: PTS
# 4         0.867151  0.093235                    X: FGA, FTA / Y: PTS
# ...

# %% [markdown]
# Podemos ver que obtenemos muy buenos resultados. Esto es debido a la buena correlación de los atributos ya que la puntuacion se ve influida por todos ellos, algunos como los tiros de 2 puntos encestados (2P) tienen mas influencia porque son los que mas se hacen en un partido pero en general todos influyen mayormente a la puntuación del jugador.

# %% [markdown]
# Finalmente, comprobaremos como se comporta el modelo al intentar prececir los puntos en base a las asistencias (AST) y de esta forma poder verificar su comportamiento.

# %%
def mse(v1, v2):
    return ((v1 - v2)**2).mean()

k = 2
x = dataset_allgames_statsNORM[["AST"]]
y = dataset_allgames_statsNORM[["PTS"]]

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y, test_size=0.20, random_state=80)

print("LINEAR REGRESSION UNIVARIADA allgames_stats.csv", "\n")

lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)

kfold = KFold(n_splits=k, shuffle=True, random_state=7)

score = lin_reg.score(x_test, y_test)
csvScore = np.mean(cross_val_score(lin_reg, x_train, y_train, cv=kfold))
mseScore = mean_squared_error(lin_reg.predict(x_test),y_test)

print("Linear Regression Score: ", score)
print("Linear Regression Cross Val Score", csvScore)
print("Linear Regression MSE: ", mseScore)

resultados = resultados.append({'Dataset:': "allgames_stats.csv", 'Model': "Linear Regresion Univariada", 'Score': score, 'Cross Val Score': csvScore, 'MSE': mseScore, 'Detalles': "X: AST / Y: PTS" }, ignore_index=True)

atribut1 = x_test["AST"].values.reshape(x_test.shape[0], 1) 
predicted = lin_reg.predict(atribut1)

plt.figure()
ax = plt.scatter(x_test["AST"], y_test)
lin = plt.plot(atribut1[:,0], predicted, 'r')
# Out:
# LINEAR REGRESSION UNIVARIADA allgames_stats.csv
#
# Linear Regression Score:  -0.001365298577992835
# Linear Regression Cross Val Score 0.0029541695886289854
# Linear Regression MSE:  1.0899938884427394

# %%
resultados
# Out:
#              Dataset:                          Model     Score  \
# 0  per_game_stats.csv    Linear Regresion Univariada  0.970873
# 1  allgames_stats.csv    Linear Regresion Univariada  0.840602
# 2  per_game_stats.csv  Linear Regresion Multivariada  0.996554
# 3  allgames_stats.csv  Linear Regresion Multivariada  0.982121
# 4  per_game_stats.csv  Linear Regresion Multivariada  0.947970
# 5  allgames_stats.csv    Linear Regresion Univariada  0.695881
# 6  per_game_stats.csv  Linear Regresion Multivariada  0.956357
# 7  allgames_stats.csv    Linear Regresion Univariada -0.001365
#
#    Cross Val Score       MSE                                Detalles
# 0         0.885137  0.052195                          X: FG / Y: PTS
# 1         0.834305  0.173506                          X: FG / Y: PTS
# 2         0.992560  0.006176            X: FG, FGA, 2P, FTA / Y: PTS
# 3         0.982507  0.019462           X: FG, FGA, GmSc, FT / Y: PTS
# ...

# %% [markdown]
# El resultado es el esperado y hemos verificado que el comportamiento del modelo es el correcto. Estamos ante los peores resultados obtenidos, pero tienen sentido. Estamos intentando predecir los puntos individuales de un jugador en un partido utilizando como atributo independiente sus asistencias, son dos atributos que no tienen nada de realción (0.059). Hubiesemos obtenido un resultado diferente si se tratase de los puntos del equipo, entonces sí que hubiesemos obtenido buenos resultados.

# %% [markdown]
# ### 5.4. Conclusiones

# %% [markdown]
# Visualicemos los resultados de todos los modelos en una tabla para poder extraer las conclusiones.

# %%
resultados
# Out:
#              Dataset:                          Model     Score  \
# 0  per_game_stats.csv    Linear Regresion Univariada  0.970873
# 1  allgames_stats.csv    Linear Regresion Univariada  0.840602
# 2  per_game_stats.csv  Linear Regresion Multivariada  0.996554
# 3  allgames_stats.csv  Linear Regresion Multivariada  0.982121
# 4  per_game_stats.csv  Linear Regresion Multivariada  0.947970
# 5  allgames_stats.csv    Linear Regresion Univariada  0.695881
# 6  per_game_stats.csv  Linear Regresion Multivariada  0.956357
# 7  allgames_stats.csv    Linear Regresion Univariada -0.001365
#
#    Cross Val Score       MSE                                Detalles
# 0         0.885137  0.052195                          X: FG / Y: PTS
# 1         0.834305  0.173506                          X: FG / Y: PTS
# 2         0.992560  0.006176            X: FG, FGA, 2P, FTA / Y: PTS
# 3         0.982507  0.019462           X: FG, FGA, GmSc, FT / Y: PTS
# ...

# %% [markdown]
# De los 8 experimentos realizados podemos extraer una serie de conclusiones.
#
# Como se puede ver en la tabla, en general podriamos decir que los modelos que se comportan mejor y se ajustan mas a los datos son aquellos donde se utiliza el dataset per_game_stats.csv. Por lo tanto, hemos verificado la hipótesis inicial. Como se ha comentado anteriormente, esto es debido a que las punuaciones no son tan diversas entre ellas al tratarse de medias y que los atributos estan muy bien correlacionados entre ellos.
#
# Los modelos con los que mejores resultados se han obtenido y por lo tanto lo que mejor se ajustan los datos son el 2 y el 3 donde se utilizaban como atributos independientes aquellos que más influian en la puntuación de un jugador. Concretamente, el mejor modelo ha sido el **Linear Regression Multivariada X: FG, FGA, 2P, FTA / Y: PTS** para el dataset **per_game_stats.csv**. Con este modelo se ha obtenido unos valores de score y cross val score de 0.99 y un valor de error de 0.006. Esto es debido a lo que se ha comentado anteriormente, el haber seleccionado los atributos mas influyentes.
#
# Por último, con las diferentes comprobaciones realizadas al final utilizando diferentes atributos de mayor y menor influencia o mayor y menor información podemos verificar que el comportamiento del modelo es el correcto ya que en todos los casos se comportaba como se esperaba y podriamos decir que es un buen modelo.
